# %%
from pathlib import Path
import pandas as pd

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_DATA= PROJECT_ROOT / "data" / "raw"

# %%
tvshows = pd.read_csv(
    RAW_DATA / "tvshows_dataset" / "TMDB_tv_dataset_v3.csv"
)

# %% [markdown]
# ## TVShows Dataset - TMDB_tv_dataset_v3

# %%
tvshows.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 168639 entries, 0 to 168638
# Data columns (total 29 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    168639 non-null  int64
#  1   name                  168634 non-null  str
#  2   number_of_seasons     168639 non-null  int64
#  3   number_of_episodes    168639 non-null  int64
#  4   original_language     168639 non-null  str
#  5   vote_count            168639 non-null  int64
#  6   vote_average          168639 non-null  float64
#  7   overview              93333 non-null   str
#  8   adult                 168639 non-null  bool
#  9   backdrop_path         77780 non-null   str
#  10  first_air_date        136903 non-null  str
#  11  last_air_date         138735 non-null  str
#  12  homepage              50998 non-null   str
#  13  in_production         168639 non-null  bool
#  14  original_name         168634 non-null  str
# ...

# %%
tvshows.head()
# Out:
#       id              name  number_of_seasons  number_of_episodes  \
# 0   1399   Game of Thrones                  8                  73
# 1  71446       Money Heist                  3                  41
# 2  66732   Stranger Things                  4                  34
# 3   1402  The Walking Dead                 11                 177
# 4  63174           Lucifer                  6                  93
#
#   original_language  vote_count  vote_average  \
# 0                en       21857         8.442
# 1                es       17836         8.257
# 2                en       16161         8.624
# 3                en       15432         8.121
# 4                en       13870         8.486
#
#                                             overview  adult  \
# 0  Seven noble families fight for control of the ...  False
# 1  To carry out the biggest heist in history, a m...  False
# 2  When a young boy vanishes, a small town uncove...  False
# ...

# %%
tvshows["id"].nunique()
# Out:
# 164705

# %%
tvshows[tvshows["id"].duplicated(keep=False)] \
    .sort_values("id") \
    [["id","name","number_of_seasons","vote_average"]].head(10)
# Out:
#             id                          name  number_of_seasons  vote_average
# 97167   237050             Archives secrètes                  1           0.0
# 164937  237050             Archives secrètes                  1           0.0
# 164938  237051  Sefure no Hinkaku The Series                  1           0.0
# 97238   237051  Sefure no Hinkaku The Series                  1           0.0
# 97152   237052                 Les Disparues                  1           0.0
# 164947  237052                 Les Disparues                  1           0.0
# 164940  237053           KEY is Good & Great                  1           0.0
# 88129   237053           KEY is Good & Great                  1           0.0
# 97110   237054             Sådan er det bare                  1           0.0
# 164942  237054             Sådan er det bare                  1           0.0

# %%
tvshows_duplicates = tvshows[tvshows["id"].duplicated(keep=False)]

tvshows_duplicates.groupby("id").size().value_counts()
# Out:
# 3    882
# 2    547
# 4    541
# Name: count, dtype: int64

# %%
tvshows[tvshows["id"] == 237050].T
# Out:
#                                                 97167   \
# id                                              237050
# name                                 Archives secrètes
# number_of_seasons                                    1
# number_of_episodes                                   5
# original_language                                   fr
# vote_count                                           0
# vote_average                                       0.0
# overview                                           NaN
# adult                                            False
# backdrop_path         /64235X8vuIZT3Up0eI6hUfyAWZe.jpg
# first_air_date                              2021-09-09
# last_air_date                               2023-10-09
# homepage                                           NaN
# in_production                                     True
# original_name                        Archives secrètes
# popularity                                       3.255
# ...
