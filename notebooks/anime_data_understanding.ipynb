# %%
from pathlib import Path
import pandas as pd

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_DATA= PROJECT_ROOT / "data" / "raw"

# %%
anime = pd.read_csv(
    RAW_DATA / "anime_dataset" / "anime-dataset-2023.csv"
)

anime_scores = pd.read_csv(
    RAW_DATA / "anime_dataset" / "users-score-2023.csv"
)

anime_users = pd.read_csv(
    RAW_DATA / "anime_dataset" / "users-details-2023.csv"
)

# %% [markdown]
# ## Anime Dataset - anime-dataset-2023

# %%
anime.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   anime_id      24905 non-null  int64
#  1   Name          24905 non-null  str
#  2   English name  24905 non-null  str
#  3   Other name    24905 non-null  str
#  4   Score         24905 non-null  str
#  5   Genres        24905 non-null  str
#  6   Synopsis      24905 non-null  str
#  7   Type          24905 non-null  str
#  8   Episodes      24905 non-null  str
#  9   Aired         24905 non-null  str
#  10  Premiered     24905 non-null  str
#  11  Status        24905 non-null  str
#  12  Producers     24905 non-null  str
#  13  Licensors     24905 non-null  str
#  14  Studios       24905 non-null  str
#  15  Source        24905 non-null  str
#  16  Duration      24905 non-null  str
#  17  Rating        24905 non-null  str
#  18  Rank          24905 non-null  str
# ...

# %%
anime.head()
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name Score  \
# 0                         カウボーイビバップ  8.75
# 1                    カウボーイビバップ 天国の扉  8.38
# 2                             トライガン  8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)  7.25
# 4                            冒険王ビィト  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
# ...

# %%
anime["anime_id"].nunique()
# Out:
# 24905

# %%
anime[["Score", "Rank", "Scored By", "Episodes"]].sample(10)
# Out:
#          Score     Rank Scored By Episodes
# 18940     5.05  11863.0     110.0      1.0
# 22785  UNKNOWN  UNKNOWN   UNKNOWN      1.0
# 2381      6.87   4510.0   16037.0     13.0
# 126       6.56   6039.0    2671.0     12.0
# 3326      5.68  10142.0     480.0      8.0
# 12410     8.32    227.0   19812.0      2.0
# 23498  UNKNOWN  UNKNOWN   UNKNOWN      1.0
# 18282  UNKNOWN  17653.0   UNKNOWN      1.0
# 20796  UNKNOWN  19478.0   UNKNOWN     26.0
# 11971     6.57   5969.0    2020.0      1.0

# %%
anime["Score"].value_counts().head(10)
# Out:
# Score
# UNKNOWN    9213
# 6.31         80
# 6.54         80
# 6.51         79
# 6.25         79
# 6.52         78
# 6.5          76
# 6.36         75
# 6.32         74
# 5.99         74
# Name: count, dtype: int64

# %%
pd.to_numeric(anime["Score"], errors="coerce").isna().sum()
# Out:
# np.int64(9213)

# %%
mask_score = pd.to_numeric(anime["Score"], errors="coerce").isna()

anime.loc[mask_score, "Score"].value_counts()
# Out:
# Score
# UNKNOWN    9213
# Name: count, dtype: int64

# %%
anime["Episodes"].value_counts().head(10)
# Out:
# Episodes
# 1.0        11532
# 12.0        1919
# 2.0         1528
# 26.0        1201
# 13.0         984
# 52.0         812
# 3.0          712
# UNKNOWN      611
# 4.0          553
# 6.0          416
# Name: count, dtype: int64

# %%
pd.to_numeric(anime["Episodes"], errors="coerce").isna().sum()
# Out:
# np.int64(611)

# %%
mask_episodes = pd.to_numeric(anime["Episodes"], errors="coerce").isna()

anime.loc[mask_episodes, "Episodes"].value_counts()
# Out:
# Episodes
# UNKNOWN    611
# Name: count, dtype: int64

# %%
anime["Rank"].value_counts().head(10)
# Out:
# Rank
# UNKNOWN    4612
# 0.0         187
# 7175.0        4
# 9618.0        4
# 6491.0        4
# 12591.0       4
# 6442.0        4
# 12881.0       4
# 10515.0       4
# 7747.0        4
# Name: count, dtype: int64

# %%
pd.to_numeric(anime["Rank"], errors="coerce").isna().sum()
# Out:
# np.int64(4612)

# %%
mask_rank = pd.to_numeric(anime["Rank"], errors="coerce").isna()

anime.loc[mask_rank, "Rank"].value_counts()
# Out:
# Rank
# UNKNOWN    4612
# Name: count, dtype: int64

# %%
anime["Scored By"].value_counts().head(10)
# Out:
# Scored By
# UNKNOWN    9213
# 121.0        35
# 128.0        35
# 150.0        33
# 172.0        33
# 130.0        32
# 134.0        31
# 152.0        31
# 123.0        30
# 124.0        30
# Name: count, dtype: int64

# %%
pd.to_numeric(anime["Scored By"], errors="coerce").isna().sum()
# Out:
# np.int64(9213)

# %%
mask_scored_by = pd.to_numeric(anime["Scored By"], errors="coerce").isna()

anime.loc[mask_scored_by, "Scored By"].value_counts()
# Out:
# Scored By
# UNKNOWN    9213
# Name: count, dtype: int64

# %%
anime[anime["Rank"] == "0.0"][
    ["anime_id","Name","Score","Rank","Scored By"]
].sample(10)
# Out:
#        anime_id                            Name    Score Rank Scored By
# 24397     55081        Tsukuyo no Nakama Atsume  UNKNOWN  0.0   UNKNOWN
# 23200     53053                  Genshin Impact  UNKNOWN  0.0   UNKNOWN
# 24613     55380                      SLoWMoTIoN  UNKNOWN  0.0   UNKNOWN
# 22033     50995  Zenryoku Usagi (Anime Project)  UNKNOWN  0.0   UNKNOWN
# 24498     55227                    Night Flower  UNKNOWN  0.0   UNKNOWN
# 24633     55401               Kakkoyoku Naritai  UNKNOWN  0.0   UNKNOWN
# 24390     55072              Kay-chan no Enikki  UNKNOWN  0.0   UNKNOWN
# 24620     55387         Kuusou Shou mo Nai Hibi  UNKNOWN  0.0   UNKNOWN
# 24904     55735                  Shijuuku Nichi  UNKNOWN  0.0   UNKNOWN
# 22338     51521        Xian Jian Qi Xia Zhuan 4  UNKNOWN  0.0   UNKNOWN

# %%
anime[anime["Rank"] == "0.0"][
    ["Score", "Scored By"]
].value_counts()
# Out:
# Score    Scored By
# UNKNOWN  UNKNOWN      187
# Name: count, dtype: int64

# %% [markdown]
# ## Anime Dataset - users-details-2023

# %%
anime_users.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 731290 entries, 0 to 731289
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Mal ID            731290 non-null  int64
#  1   Username          731289 non-null  str
#  2   Gender            224383 non-null  str
#  3   Birthday          168068 non-null  str
#  4   Location          152805 non-null  str
#  5   Joined            731290 non-null  str
#  6   Days Watched      731282 non-null  float64
#  7   Mean Score        731282 non-null  float64
#  8   Watching          731282 non-null  float64
#  9   Completed         731282 non-null  float64
#  10  On Hold           731282 non-null  float64
#  11  Dropped           731282 non-null  float64
#  12  Plan to Watch     731282 non-null  float64
#  13  Total Entries     731282 non-null  float64
#  14  Rewatched         731282 non-null  float64
#  15  Episodes Watched  731282 non-null  float64
# ...

# %%
anime_users.head()
# Out:
#    Mal ID Username  Gender                   Birthday              Location  \
# 0       1    Xinil    Male  1985-03-04T00:00:00+00:00            California
# 1       3  Aokaado    Male                        NaN          Oslo, Norway
# 2       4  Crystal  Female                        NaN  Melbourne, Australia
# 3       9   Arcane     NaN                        NaN                   NaN
# 4      18      Mad     NaN                        NaN                   NaN
#
#                       Joined  Days Watched  Mean Score  Watching  Completed  \
# 0  2004-11-05T00:00:00+00:00         142.3        7.37       1.0      233.0
# 1  2004-11-11T00:00:00+00:00          68.6        7.34      23.0      137.0
# 2  2004-11-13T00:00:00+00:00         212.8        6.68      16.0      636.0
# 3  2004-12-05T00:00:00+00:00          30.0        7.71       5.0       54.0
# 4  2005-01-03T00:00:00+00:00          52.0        6.27       1.0      114.0
#
# ...

# %%
anime_users["Mal ID"].nunique()
# Out:
# 731290

# %%
anime_users.isnull().sum().sort_values(ascending=False)
# Out:
# Location            578485
# Birthday            563222
# Gender              506907
# Days Watched             8
# Mean Score               8
# On Hold                  8
# Completed                8
# Watching                 8
# Plan to Watch            8
# Total Entries            8
# Rewatched                8
# Dropped                  8
# Episodes Watched         8
# Username                 1
# Joined                   0
# Mal ID                   0
# dtype: int64

# %%
anime_users[anime_users["Username"].isna()]
# Out:
#        Mal ID Username Gender Birthday Location                     Joined  \
# 19618   20930      NaN    NaN      NaN      NaN  2007-11-09T00:00:00+00:00
#
#        Days Watched  Mean Score  Watching  Completed  On Hold  Dropped  \
# 19618          58.8        7.59       8.0      236.0      8.0      3.0
#
#        Plan to Watch  Total Entries  Rewatched  Episodes Watched
# 19618           17.0          272.0       14.0            3447.0

# %%
anime_users[
    anime_users["Days Watched"].isna()
]
# Out:
#         Mal ID         Username  Gender                   Birthday  \
# 7532      8682     DeleteMe3409  Female                        NaN
# 74352    79090     rosycrystals  Female  1993-11-29T00:00:00+00:00
# 120266  125668     BlazingDevil    Male  1995-07-07T00:00:00+00:00
# 147943  160113  FuckedUpProfile  Female  1993-06-19T00:00:00+00:00
# 196115  231825   Account_Closed  Female  1994-04-22T00:00:00+00:00
# 196899  232646         -Lovely-  Female  1994-04-22T00:00:00+00:00
# 233070  277237      sarah_sweet  Female  1997-08-14T00:00:00+00:00
# 470599  561555    RaisinMuffins    Male                        NaN
#
#                                    Location                     Joined  \
# 7532                                    NaN  2007-07-27T00:00:00+00:00
# 74352                                Kansas  2008-07-23T00:00:00+00:00
# 120266  Kamloops British Columbia in Canada  2008-12-20T00:00:00+00:00
# 147943                      Organisation 13  2009-03-17T00:00:00+00:00
# ...

# %% [markdown]
# ## Anime Dataset - users-score-2023

# %%
anime_scores.info(show_counts=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24325191 entries, 0 to 24325190
# Data columns (total 5 columns):
#  #   Column       Non-Null Count     Dtype
# ---  ------       --------------     -----
#  0   user_id      24325191 non-null  int64
#  1   Username     24324959 non-null  str
#  2   anime_id     24325191 non-null  int64
#  3   Anime Title  24325191 non-null  str
#  4   rating       24325191 non-null  int64
# dtypes: int64(3), str(2)
# memory usage: 927.9 MB

# %%
anime_scores.head()
# Out:
#    user_id Username  anime_id             Anime Title  rating
# 0        1    Xinil        21               One Piece       9
# 1        1    Xinil        48             .hack//Sign       7
# 2        1    Xinil       320                  A Kite       5
# 3        1    Xinil        49        Aa! Megami-sama!       8
# 4        1    Xinil       304  Aa! Megami-sama! Movie       8

# %%
anime_scores[["user_id", "anime_id"]].duplicated().sum()
# Out:
# np.int64(0)

# %%
anime_scores[anime_scores["Username"].isna()].sample(10)
# Out:
#          user_id Username  anime_id  \
# 1571911    20930      NaN      1033
# 1571735    20930      NaN       150
# 1571802    20930      NaN     26055
# 1571877    20930      NaN     34475
# 1571743    20930      NaN      1818
# 1571925    20930      NaN       849
# 1571832    20930      NaN        87
# 1571818    20930      NaN        82
# 1571933    20930      NaN      1303
# 1571784    20930      NaN     37141
#
#                                                Anime Title  rating
# 1571911                                       Sennen Joyuu       8
# 1571735                                             Blood+       7
# 1571802  JoJo no Kimyou na Bouken Part 3: Stardust Crus...       7
# 1571877                   Monster Strike: Rain of Memories       7
# 1571743                                           Claymore       9
# 1571925                         Suzumiya Haruhi no Yuuutsu       9
# 1571832             Kidou Senshi Gundam: Gyakushuu no Char       6
# ...

# %%
anime_scores[anime_scores["Username"].isna()]["user_id"].nunique()
# Out:
# 1

# %%
anime_scores["rating"].value_counts().sort_index()
# Out:
# rating
# 1       98069
# 2      132092
# 3      233675
# 4      562822
# 5     1379480
# 6     2766482
# 7     5452152
# 8     6060484
# 9     4429914
# 10    3210021
# Name: count, dtype: int64
