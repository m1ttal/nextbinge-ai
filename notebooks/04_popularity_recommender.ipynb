# %%
from pathlib import Path
import sys
import pandas as pd
import fastparquet

# %%
PROJECT_ROOT = Path.cwd().parent

sys.path.append(str(PROJECT_ROOT))

# %%
dim_items = pd.read_parquet(f"{PROJECT_ROOT}/data/processed/movies/dim_items.parquet", engine="fastparquet")
item_genres = pd.read_parquet(f"{PROJECT_ROOT}/data/processed/movies/item_genres.parquet", engine="fastparquet")

# %%
from src.recommenders.popularity import (
    get_top_movies,
    get_top_movies_by_genre,
    get_available_genres
)

# %%
get_top_movies(
    dim_items,
    top_n=20
)[
    [
        "title",
        "vote_average",
        "vote_count",
        "weighted_rating"
    ]
]
# Out:
#                                  title  vote_average  vote_count  \
# 314           The Shawshank Redemption           8.5      8358.0
# 834                      The Godfather           8.5      6024.0
# 10306      Dilwale Dulhania Le Jayenge           9.1       661.0
# 12477                  The Dark Knight           8.3     12269.0
# 2842                        Fight Club           8.3      9678.0
# 292                       Pulp Fiction           8.3      8670.0
# 522                   Schindler's List           8.3      4436.0
# 23655                         Whiplash           8.3      4376.0
# 5480                     Spirited Away           8.3      3968.0
# 2210                 Life Is Beautiful           8.3      3643.0
# 1178            The Godfather: Part II           8.3      3418.0
# 1152   One Flew Over the Cuckoo's Nest           8.3      3001.0
# 351                       Forrest Gump           8.2      8147.0
# ...

# %%
get_top_movies_by_genre(
    dim_items,
    item_genres,
    genre="Action",
    top_n=20
)[
    [
        "title",
        "vote_average",
        "vote_count",
        "weighted_rating"
    ]
]
# Out:
#                                                    title  vote_average  \
# 12477                                    The Dark Knight           8.3
# 15474                                          Inception           8.1
# 1154                             The Empire Strikes Back           8.2
# 6999       The Lord of the Rings: The Return of the King           8.1
# 256                                            Star Wars           8.1
# 4862   The Lord of the Rings: The Fellowship of the Ring           8.0
# 5813               The Lord of the Rings: The Two Towers           8.0
# 23735                            Guardians of the Galaxy           7.9
# 2457                                          The Matrix           7.9
# 13600                               Inglourious Basterds           7.9
# 3455                                           Gladiator           7.9
# 1167                                  Return of the Jedi           7.9
# ...

# %%
get_top_movies(dim_items)
# Out:
#        item_id  source_item_id                            title  \
# 314        315             278         The Shawshank Redemption
# 834        835             238                    The Godfather
# 10306    10307           19404      Dilwale Dulhania Le Jayenge
# 12477    12478             155                  The Dark Knight
# 2842      2843             550                       Fight Club
# 292        293             680                     Pulp Fiction
# 522        523             424                 Schindler's List
# 23655    23656          244786                         Whiplash
# 5480      5481             129                    Spirited Away
# 2210      2211             637                Life Is Beautiful
# 1178      1179             240           The Godfather: Part II
# 1152      1153             510  One Flew Over the Cuckoo's Nest
# 351        352              13                     Forrest Gump
# 1154      1155            1891          The Empire Strikes Back
# ...

# %%
get_top_movies_by_genre(
    dim_items,
    item_genres,
    "Adventure"
)
# Out:
#        item_id  source_item_id  \
# 15474    15475           27205
# 22863    22864          157336
# 1154      1155            1891
# 6999      7000             122
# 256        257              11
# 5480      5481             129
# 4862      4863             120
# 5813      5814             121
# 23735    23736          118340
# 1225      1226             105
# 17429    17430           12445
# 3455      3456              98
# 13719    13720           14160
# 1167      1168            1892
# 24437    24438          177572
# 7724      7725             673
# 9695      9696            4935
# 2883      2884             128
# 30026    30027          286217
# 36223    36224          269149
#
#                                                    title  \
# 15474                                          Inception
# 22863                                       Interstellar
# 1154                             The Empire Strikes Back
# 6999       The Lord of the Rings: The Return of the King
# ...

# %%
get_available_genres(item_genres)
# Out:
# ['Action',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Foreign',
#  'History',
#  'Horror',
#  'Music',
#  'Mystery',
#  'Romance',
#  'Science Fiction',
#  'TV Movie',
#  'Thriller',
#  'War',
#  'Western']
